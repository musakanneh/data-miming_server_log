# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from datetime import datetime
import pytz
#%h %l %u %t \"%r\" %>s %b \"%{Referer}i\" \"%{User-agent}i\"
def parse_str(x):
    """
    Returns the string delimited by two characters.
    """
    if x is None:
        return '-'
    return x[1:-1]

# %%
def parse_int(x):
    """Returns parsed string if no error occured during parse else returns 0"""
    if x is None:
        return 0
    try:
        y = int(x)
        return y
    except ValueError:
        return 0

# %%
def parse_datetime(x):
    '''
    Parses datetime with timezone formatted as:
        `[day/month/year:hour:minute:second zone]`

    Example:
        `>>> parse_datetime('13/Nov/2015:11:45:42 +0000')`
        `datetime.datetime(2015, 11, 3, 11, 45, 4, tzinfo=<UTC>)`

    Due to problems parsing the timezone (`%z`) with `datetime.strptime`, the
    timezone will be obtained using the `pytz` library.
    '''
    try:
        dt = datetime.strptime(x[1:-7], '%d/%b/%Y:%H:%M:%S')
        dt_tz = int(x[-6:-3])*60+int(x[-3:-1])
        return dt.replace(tzinfo=pytz.FixedOffset(dt_tz))
    except ValueError:
        return '-'

# %%
import re
import pandas as pd
conv = {'time': parse_datetime,
        'request': parse_str,
        'status': parse_int,
        'size': parse_int,
        'referer': parse_str,
        'user_agent': parse_str}
df = pd.read_csv('/content/drive/My Drive/web log-data/new_log',
                    header=None,
                    error_bad_lines=False,                    sep=r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])',
                    engine='python',
                    na_values='-',
                    usecols=[0, 3, 4, 5, 6, 7, 8],
                    #names=['ip', 'time', 'request', 'status', 'size', 'referer', 'user_agent'],
                    names=['Client_IP_address', 'Time_of_activity','Requested_Page', 'Status_Code', 'Size_of_Page', 'Referer_page','Client_Device'],
                    converters=conv,                  )              
df.head()
# Out:
#   Client_IP_address  ...                                      Client_Device
# 0   109.169.248.247  ...  "Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/2...
# 1   109.169.248.247  ...  "Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/2...
# 2       46.72.177.4  ...  "Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/2...
# 3       46.72.177.4  ...  "Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/2...
# 4    83.167.113.100  ...  "Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/2...
#
# [5 rows x 7 columns]

# %% [markdown]
# ## Top 10 frequent visitors of the website

# %%
ip=set(df['Client_IP_address'])
# print(len(ip))
devices=set(df['Client_Device'])
len(devices)
dict_={}
for i,row in df.iterrows():
    if(tuple((row['Client_IP_address'],row['Client_Device'])) in dict_):
        dict_[tuple((row['Client_IP_address'],row['Client_Device']))]+=1
    
    else:
        dict_[tuple((row['Client_IP_address'],row['Client_Device']))]=1
frequent = sorted(dict_, key = dict_.get, reverse = True)
frequent_10 = frequent[:10]
for i,j in enumerate(frequent_10, start=1):
    print(i,"",j)
# Out:
# 1  ('205.167.170.15', '"Go-http-client/1.1"')
# 2  ('79.142.95.122', '"Mozilla/5.0 (Windows NT 5.1; rv:29.0) Gecko/20100101 Firefox/29.0"')
# 3  ('148.251.50.49', '"-"')
# 4  ('205.167.170.15', '"python-requests/1.2.3 CPython/2.7.5 Linux/3.14.27-100.fc19.x86_64"')
# 5  ('37.1.206.196', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/31.0.1650.57 Safari/537.36"')
# 6  ('91.200.12.22', '"Opera/9.80 (Windows NT 5.1; U; ru) Presto/2.9.168 Version/11.50"')
# 7  ('213.150.254.81', '"Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0)"')
# 8  ('84.112.161.41', '"Mozilla/5.0 (Linux; Android 5.0.2; HTC_One Build/LRX22G) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/33.0.0.0 Mobile Safari/537.36"')
# 9  ('205.167.170.15', '"Mozilla/5.0 (X11; Linux x86_64; rv:44.0) Gecko/20100101 Firefox/44.0"')
# 10  ('84.58.165.21', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.11; rv:45.0) Gecko/20100101 Firefox/45.0"')

# %%
time=[]
page=[]
al=[]
for i in list(dict_)[:500]:
    for j,row in df.iterrows():
        if(i==tuple((row['Client_IP_address'],row['Client_Device']))):
            time.append(row['Time_of_activity'])
            page.append(row['Requested_Page'])
            al.append(i)

# %%
al[:5]
# Out:
# [('109.169.248.247',
#   '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"'),
#  ('109.169.248.247',
#   '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"'),
#  ('109.169.248.247',
#   '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"'),
#  ('109.169.248.247',
#   '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"'),
#  ('109.169.248.247',
#   '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"')]

# %%
time[:5]
# Out:
# ['[12/Dec/2015:18:25:11 +0100]',
#  '[12/Dec/2015:18:25:11 +0100]',
#  '[13/Dec/2015:12:10:05 +0100]',
#  '[13/Dec/2015:12:10:05 +0100]',
#  '[13/Dec/2015:12:43:46 +0100]']

# %%
page[:5]
# Out:
# ['"GET /administrator/ HTTP/1.1"',
#  '"POST /administrator/index.php HTTP/1.1"',
#  '"GET /administrator/ HTTP/1.1"',
#  '"POST /administrator/index.php HTTP/1.1"',
#  '"GET /administrator/ HTTP/1.1"']

# %%
df1=pd.DataFrame({'Time':time,'Pages':page,'Client':al})
df1.head(40)
# Out:
#                             Time  ...                                             Client
# 0   [12/Dec/2015:18:25:11 +0100]  ...  (109.169.248.247, "Mozilla/5.0 (Windows NT 6.0...
# 1   [12/Dec/2015:18:25:11 +0100]  ...  (109.169.248.247, "Mozilla/5.0 (Windows NT 6.0...
# 2   [13/Dec/2015:12:10:05 +0100]  ...  (109.169.248.247, "Mozilla/5.0 (Windows NT 6.0...
# 3   [13/Dec/2015:12:10:05 +0100]  ...  (109.169.248.247, "Mozilla/5.0 (Windows NT 6.0...
# 4   [13/Dec/2015:12:43:46 +0100]  ...  (109.169.248.247, "Mozilla/5.0 (Windows NT 6.0...
# 5   [13/Dec/2015:12:43:46 +0100]  ...  (109.169.248.247, "Mozilla/5.0 (Windows NT 6.0...
# 6   [12/Dec/2015:18:31:08 +0100]  ...  (46.72.177.4, "Mozilla/5.0 (Windows NT 6.0; rv...
# 7   [12/Dec/2015:18:31:08 +0100]  ...  (46.72.177.4, "Mozilla/5.0 (Windows NT 6.0; rv...
# 8   [14/Dec/2015:16:39:27 +0100]  ...  (46.72.177.4, "Mozilla/5.0 (Windows NT 6.0; rv...
# 9   [14/Dec/2015:16:39:28 +0100]  ...  (46.72.177.4, "Mozilla/5.0 (Windows NT 6.0; rv...
# 10  [15/Dec/2015:18:16:52 +0100]  ...  (46.72.177.4, "Mozilla/5.0 (Windows NT 6.0; rv...
# 11  [15/Dec/2015:18:16:52 +0100]  ...  (46.72.177.4, "Mozilla/5.0 (Windows NT 6.0; rv...
# 12  [17/Dec/2015:19:43:47 +0100]  ...  (46.72.177.4, "Mozilla/5.0 (Windows NT 6.0; rv...
# 13  [17/Dec/2015:19:43:47 +0100]  ...  (46.72.177.4, "Mozilla/5.0 (Windows NT 6.0; rv...
# 14  [12/Dec/2015:18:31:25 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 15  [12/Dec/2015:18:31:25 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 16  [12/Dec/2015:19:37:49 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 17  [12/Dec/2015:19:37:50 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 18  [12/Dec/2015:20:42:54 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 19  [12/Dec/2015:20:42:54 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 20  [12/Dec/2015:21:24:36 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 21  [12/Dec/2015:21:24:36 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 22  [12/Dec/2015:23:32:51 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 23  [12/Dec/2015:23:32:51 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 24  [13/Dec/2015:02:30:28 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 25  [13/Dec/2015:06:06:19 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 26  [13/Dec/2015:06:06:19 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 27  [13/Dec/2015:12:52:45 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 28  [13/Dec/2015:12:52:46 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 29  [13/Dec/2015:14:14:55 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 30  [13/Dec/2015:14:14:55 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 31  [13/Dec/2015:17:06:06 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 32  [13/Dec/2015:17:06:06 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 33  [14/Dec/2015:06:04:29 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 34  [14/Dec/2015:06:04:29 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 35  [14/Dec/2015:10:58:57 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 36  [14/Dec/2015:10:58:57 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 37  [15/Dec/2015:03:58:00 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 38  [15/Dec/2015:03:58:00 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
# 39  [15/Dec/2015:10:24:24 +0100]  ...  (83.167.113.100, "Mozilla/5.0 (Windows NT 6.0;...
#
# [40 rows x 3 columns]

# %% [markdown]
# ## Five frequent pages which the users visit before visiting this particular web site

# %%
referers = df['Referer_page'].dropna(how='all')
from urllib.parse import urlparse
ref=[]
for i in referers:       
    parsed_uri = urlparse(i.replace('"', ''))
    result = '{uri.scheme}://{uri.netloc}/'.format(uri=parsed_uri)
    ref.append(result)
word_counter = {}
for url in ref:
    if url in word_counter:
        word_counter[url] += 1
    else:
        word_counter[url] = 1
popular_words = sorted(word_counter, key = word_counter.get, reverse = True)
top_5 = popular_words[:6]
for i in top_5:
    if(i==':///'''):
        top_5.remove(i)
for i,j in enumerate(top_5,start=1):
    print(i,"",j)
# Out:
# 1  http://almhuette-raith.at/
# 2  http://www.almhuette-raith.at/
# 3  https://search.yahoo.com/
# 4  http://www.almenland.at/
# 5  https://www.bing.com/

# %%
Pages_visited_per_session=list(df1['Pages'])
Pages_accessed={}
for i,row in df1.iterrows():
    if(row['Client'] in Pages_accessed):
        Pages_accessed[row['Client']].append(row['Pages'])    
    else:
        Pages_accessed[row['Client']]=[row['Pages']]
for i in Pages_accessed:
    print('\n Client {} accessed these pages \n {} \n'.format(i,Pages_accessed[i]))
all_pages=[]
for i in Pages_accessed:
    all_pages.append(Pages_accessed[i])
# Out:
#  Client ('109.169.248.247', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('46.72.177.4', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('83.167.113.100', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('95.29.198.15', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('109.184.11.34', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('91.227.29.79', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('90.154.66.233', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('95.140.24.131', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('95.188.245.16', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('46.72.213.133', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('178.204.119.130', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('178.35.0.41', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('92.252.165.97', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('31.202.233.212', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('83.219.151.232', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('46.72.184.174', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('176.116.138.82', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('178.47.189.163', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('178.44.144.231', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('213.24.134.32', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('191.182.199.16', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"') accessed these pages
#  ['"GET / HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/css/bowslideshow.css HTTP/1.1"', '"GET /templates/_system/css/general.css HTTP/1.1"', '"GET /media/system/js/caption.js HTTP/1.1"', '"GET /templates/jp_hotel/css/template.css HTTP/1.1"', '"GET /templates/jp_hotel/css/layout.css HTTP/1.1"', '"GET /templates/jp_hotel/css/menu.css HTTP/1.1"', '"GET /templates/jp_hotel/css/suckerfish.css HTTP/1.1"', '"GET /templates/jp_hotel/js/moomenu.js HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/js/sliderman.1.3.0.js HTTP/1.1"', '"GET /media/system/js/mootools.js HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_01.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_02.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_03.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_06.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_04.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_05.jpg HTTP/1.1"', '"GET /templates/jp_hotel/images/logo.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_07.jpg HTTP/1.1"', '"GET /images/stories/raith/almhuette_raith.jpg HTTP/1.1"', '"GET /images/stories/raith/wohnraum.jpg HTTP/1.1"', '"GET /images/stories/raith/grillplatz.jpg HTTP/1.1"', '"GET /images/stories/raith/almenland_logo.jpg HTTP/1.1"', '"GET /images/stories/raith/oststeiermark.png HTTP/1.1"', '"GET /images/stories/raith/garage.jpg HTTP/1.1"', '"GET /images/stories/raith/steiermark_herz.png HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/images/image_shadow.png HTTP/1.1"', '"GET /templates/jp_hotel/images/content_heading.gif HTTP/1.1"', '"GET /images/bg_raith.jpg HTTP/1.1"', '"GET /templates/jp_hotel/images/module_heading.gif HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_02.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_04.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_05.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_06.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_03.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_01.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_07.jpg HTTP/1.1"']
#
#
#  Client ('176.212.187.84', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('180.180.104.183', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Maxthon/4.4.3.4000 Chrome/30.0.1599.101 Safari/537.36"') accessed these pages
#  ['"GET /apache-log/access.log HTTP/1.1"']
#
#
#  Client ('176.194.214.104', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('189.16.1.18', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('177.6.184.110', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('81.88.222.215', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('66.249.66.19', '"Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)"') accessed these pages
#  ['"GET /index.php?option=com_content&view=article&id=46&Itemid=54 HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /apache-log/ HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=2%3Awinterfotos&Itemid=53&limitstart=20 HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=46&Itemid=54 HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=3:almhuette-raith&Itemid=53 HTTP/1.1"', '"GET /index.php?option=com_content&view=frontpage HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=49&Itemid=55 HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /index.php?option=com_content&view=frontpage HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=1%3Aalmhuette-raith&Itemid=53 HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /ekszhwvyuvm.html HTTP/1.1"', '"GET /index.php?option=com_content&view=frontpage HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /index.php?option=com_content&view=frontpage HTTP/1.1"']
#
#
#  Client ('87.255.246.50', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('46.116.249.142', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('46.39.229.183', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('46.72.185.236', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('92.248.235.103', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('109.252.11.47', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('2.93.207.163', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('178.34.161.222', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('188.45.108.168', '"Mozilla/5.0 (Linux; Android 4.4.2; de-at; SAMSUNG GT-I9301I Build/KOT49H) AppleWebKit/537.36 (KHTML, like Gecko) Version/1.5 Chrome/28.0.1500.94 Mobile Safari/537.36"') accessed these pages
#  ['"GET / HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/css/bowslideshow.css HTTP/1.1"', '"GET /templates/_system/css/general.css HTTP/1.1"', '"GET /templates/jp_hotel/css/template.css HTTP/1.1"', '"GET /templates/jp_hotel/css/layout.css HTTP/1.1"', '"GET /templates/jp_hotel/css/menu.css HTTP/1.1"', '"GET /templates/jp_hotel/css/suckerfish.css HTTP/1.1"', '"GET /media/system/js/caption.js HTTP/1.1"', '"GET /templates/jp_hotel/js/moomenu.js HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/js/sliderman.1.3.0.js HTTP/1.1"', '"GET /media/system/js/mootools.js HTTP/1.1"', '"GET /templates/jp_hotel/images/logo.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_02.jpg HTTP/1.1"', '"GET /images/stories/raith/wohnraum.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_01.jpg HTTP/1.1"', '"GET /images/stories/raith/grillplatz.jpg HTTP/1.1"', '"GET /images/stories/raith/garage.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_03.jpg HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_06.jpg HTTP/1.1"', '"GET /images/stories/raith/almhuette_raith.jpg HTTP/1.1"', '"GET /modules/mod_bowslideshow/tmpl/images/image_shadow.png HTTP/1.1"', '"GET /templates/jp_hotel/images/content_heading.gif HTTP/1.1"', '"GET /templates/jp_hotel/images/module_heading.gif HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_05.jpg HTTP/1.1"', '"GET /images/stories/raith/almenland_logo.jpg HTTP/1.1"', '"GET /images/stories/raith/steiermark_herz.png HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_04.jpg HTTP/1.1"', '"GET /images/stories/raith/oststeiermark.png HTTP/1.1"', '"GET /images/stories/slideshow/almhuette_raith_07.jpg HTTP/1.1"', '"GET /images/bg_raith.jpg HTTP/1.1"', '"GET /favicon.ico HTTP/1.1"']
#
#
#  Client ('188.254.126.77', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('95.153.132.103', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('78.81.147.127', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('195.91.157.50', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('5.140.164.122', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.0"', '"POST /administrator/index.php HTTP/1.0"', '"GET /administrator/ HTTP/1.0"', '"POST /administrator/index.php HTTP/1.0"', '"GET /administrator/ HTTP/1.0"', '"POST /administrator/index.php HTTP/1.0"', '"GET /administrator/ HTTP/1.0"', '"POST /administrator/index.php HTTP/1.0"', '"GET /administrator/ HTTP/1.0"', '"POST /administrator/index.php HTTP/1.0"', '"GET /administrator/ HTTP/1.0"', '"POST /administrator/index.php HTTP/1.0"', '"GET /administrator/ HTTP/1.0"', '"POST /administrator/index.php HTTP/1.0"', '"GET /administrator/ HTTP/1.0"', '"POST /administrator/index.php HTTP/1.0"', '"GET /administrator/ HTTP/1.0"', '"POST /administrator/index.php HTTP/1.0"', '"GET /administrator/ HTTP/1.0"', '"POST /administrator/index.php HTTP/1.0"', '"GET /administrator/ HTTP/1.0"', '"POST /administrator/index.php HTTP/1.0"']
#
#
#  Client ('92.112.194.169', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('212.12.28.122', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('77.243.115.178', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('94.233.147.245', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('189.45.201.226', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36"') accessed these pages
#  ['"GET /apache-log/access.log HTTP/1.1"']
#
#
#  Client ('176.213.82.180', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('31.173.80.169', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('213.24.132.155', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('189.13.146.143', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('130.255.13.57', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('62.141.121.10', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('185.17.135.224', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('180.76.15.137', '"Mozilla/5.0 (Windows NT 5.1; rv:6.0.2) Gecko/20100101 Firefox/6.0.2"') accessed these pages
#  ['"GET /robots.txt HTTP/1.1"', '"GET /robots.txt HTTP/1.1"']
#
#
#  Client ('37.215.38.205', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('95.29.85.222', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('5.18.95.55', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('91.211.128.249', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('37.45.11.101', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('178.252.127.248', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('66.249.66.5', '"Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)"') accessed these pages
#  ['"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=1:almhuette-raith&Itemid=53 HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"']
#
#
#  Client ('92.244.224.113', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('2.93.161.253', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('188.191.175.165', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('188.17.60.192', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('109.172.31.79', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('66.249.66.16', '"Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)"') accessed these pages
#  ['"GET / HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=46&Itemid=54 HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /apache-log/ HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=46&Itemid=54 HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=46&Itemid=54 HTTP/1.1"', '"GET /index.php?option=com_phocagallery&view=category&id=2%3Awinterfotos&Itemid=53 HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=46&Itemid=54 HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /index.php?option=com_content&view=frontpage HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /apache-log/ HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=46&Itemid=54 HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /apache-log/access.log HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"']
#
#
#  Client ('2.134.205.87', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('83.237.109.103', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('46.61.242.117', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('107.168.140.56', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Maxthon/4.4.3.4000 Chrome/30.0.1599.101 Safari/537.36"') accessed these pages
#  ['"GET /apache-log/access.log HTTP/1.0"']
#
#
#  Client ('80.66.158.8', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('5.164.167.182', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('95.105.39.25', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('201.79.97.230', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('41.33.191.114', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Maxthon/4.4.3.4000 Chrome/30.0.1599.101 Safari/537.36"') accessed these pages
#  ['"GET /apache-log/access.log HTTP/1.1"']
#
#
#  Client ('46.61.15.146', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('87.159.214.230', '"T-Online Browser (Windows NT 6.1; de)"') accessed these pages
#  ['"GET / HTTP/1.1"']
#
#
#  Client ('84.18.126.216', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('188.123.230.195', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('89.105.140.247', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('176.105.13.78', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('94.41.213.58', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('109.106.143.62', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('178.204.7.30', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('159.182.107.1', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36"') accessed these pages
#  ['"GET /apache-log/access.log HTTP/1.0"']
#
#
#  Client ('91.227.190.44', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('213.167.43.54', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('46.180.164.219', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('187.58.71.107', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('95.153.135.72', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('92.101.154.122', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('128.70.41.172', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('46.0.172.1', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('91.76.34.203', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('177.201.52.125', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('62.192.246.119', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('89.28.162.61', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('188.230.81.36', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('192.227.224.48', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Iron/29.0.1600.1 Chrome/29.0.1600.1 Safari/537.36"') accessed these pages
#  ['"GET /apache-log/access.log HTTP/1.0"']
#
#
# ...
#
#
#  Client ('78.171.222.103', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Maxthon/4.4.4.600 Chrome/30.0.1599.101 Safari/537.36"') accessed these pages
#  ['"GET /apache-log/access.log HTTP/1.1"']
#
#
#  Client ('37.146.123.45', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('192.99.71.135', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Maxthon/4.4.4.600 Chrome/30.0.1599.101 Safari/537.36"') accessed these pages
#  ['"GET /apache-log/access.log HTTP/1.1"']
#
#
#  Client ('162.244.14.154', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Maxthon/4.4.3.4000 Chrome/30.0.1599.101 Safari/537.36"') accessed these pages
#  ['"GET /apache-log/access.log HTTP/1.1"']
#
#
#  Client ('66.249.65.24', '"Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)"') accessed these pages
#  ['"GET /apache-log/access.log HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=50&Itemid=56 HTTP/1.1"']
#
#
#  Client ('66.249.73.142', '"Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)"') accessed these pages
#  ['"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"']
#
#
#  Client ('178.65.71.217', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('180.180.100.58', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Maxthon/4.4.4.600 Chrome/30.0.1599.101 Safari/537.36"') accessed these pages
#  ['"GET /apache-log/access.log HTTP/1.1"']
#
#
#  Client ('5.141.220.43', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('88.200.215.102', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('213.87.144.24', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('189.51.5.2', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('54.210.28.17', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.65 Safari/537.36"') accessed these pages
#  ['"GET / HTTP/1.1"']
#
#
#  Client ('193.111.140.106', '"Mozilla/5.0 (compatible; MJ12bot/v1.4.5; http://www.majestic12.co.uk/bot.php?+)"') accessed these pages
#  ['"GET /robots.txt HTTP/1.0"', '"GET /index.php?option=com_phocagallery&view=category&id=1:almhuette-raith&Itemid=53&limitstart=20 HTTP/1.0"', '"GET /index.php?option=com_phocagallery&view=category&id=2:winterfotos&Itemid=53&limitstart=20 HTTP/1.0"']
#
#
#  Client ('46.0.68.27', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('93.126.34.162', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Maxthon/4.4.4.600 Chrome/30.0.1599.101 Safari/537.36"') accessed these pages
#  ['"GET /apache-log/access.log HTTP/1.1"']
#
#
#  Client ('85.26.164.17', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('91.221.233.82', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Maxthon/4.4.4.600 Chrome/30.0.1599.101 Safari/537.36"') accessed these pages
#  ['"GET /apache-log/access.log HTTP/1.1"']
#
#
#  Client ('5.1.50.242', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('37.144.109.217', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('66.249.73.151', '"Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)"') accessed these pages
#  ['"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET /index.php?format=feed&type=atom HTTP/1.1"', '"GET /index.php?option=com_content&view=article&id=47:almhuette-raith&catid=34:raith HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"']
#
#
#  Client ('5.164.156.191', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('176.43.112.140', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Maxthon/4.4.4.600 Chrome/30.0.1599.101 Safari/537.36"') accessed these pages
#  ['"GET /apache-log/access.log HTTP/1.1"']
#
#
#  Client ('37.78.117.151', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('88.198.140.4', '"Mozilla/5.0 (Windows NT 6.1; WOW64; rv:18.0) Gecko/20100101 Firefox/18.0"') accessed these pages
#  ['"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"', '"GET / HTTP/1.1"', '"GET / HTTP/1.1"', '"GET /robots.txt HTTP/1.1"']
#
#
#  Client ('198.23.250.94', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Maxthon/4.4.4.600 Chrome/30.0.1599.101 Safari/537.36"') accessed these pages
#  ['"GET /apache-log/access.log HTTP/1.0"', '"GET /templates/jp_hotel/css/template.css HTTP/1.1"']
#
#
#  Client ('23.94.54.14', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Maxthon/4.4.4.600 Chrome/30.0.1599.101 Safari/537.36"') accessed these pages
#  ['"GET /templates/jp_hotel/css/template.css HTTP/1.0"']
#
#
#  Client ('31.42.47.71', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('178.63.86.11', '"Mozilla/5.0 (compatible; MJ12bot/v1.4.5; http://www.majestic12.co.uk/bot.php?+)"') accessed these pages
#  ['"GET /robots.txt HTTP/1.0"', '"GET /index.php HTTP/1.0"', '"GET /index.php?format=feed&type=atom HTTP/1.0"', '"GET /index.php?format=feed&type=rss HTTP/1.0"', '"GET /index.php?option=com_content&view=article&id=46&Itemid=54 HTTP/1.0"', '"GET /index.php?option=com_content&view=article&id=49&Itemid=55 HTTP/1.0"', '"GET /index.php?option=com_content&view=article&id=50&Itemid=56 HTTP/1.0"', '"GET /index.php?option=com_phocagallery&view=category&id=1&Itemid=53 HTTP/1.0"', '"GET /index.php?option=com_phocagallery&view=category&id=4:ferienwohnung2&Itemid=53 HTTP/1.0"']
#
#
#  Client ('212.95.7.138', '"Mozilla/5.0 (iPhone; CPU iPhone OS 9_1 like Mac OS X) AppleWebKit/601.1.46 (KHTML, like Gecko) Version/9.0 Mobile/13B143 Safari/601.1"') accessed these pages
#  ['"GET /templates/_system/css/general.css HTTP/1.1"', '"GET /templates/_system/css/general.css HTTP/1.1"', '"GET /templates/_system/css/general.css HTTP/1.1"']
#
#
#  Client ('83.219.151.133', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('81.177.127.28', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('188.186.198.167', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('5.139.222.12', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('95.72.236.86', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('79.111.88.247', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('66.249.73.160', '"Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)"') accessed these pages
#  ['"GET / HTTP/1.1"']
#
#
#  Client ('89.28.162.57', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('217.74.175.196', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('52.192.103.119', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Maxthon/4.4.4.600 Chrome/30.0.1599.101 Safari/537.36"') accessed these pages
#  ['"GET /apache-log/access.log HTTP/1.1"']
#
#
#  Client ('188.162.229.109', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('177.99.42.35', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('5.175.89.172', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('85.115.248.207', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('46.72.202.185', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('5.142.20.249', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('136.169.192.90', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('31.173.80.225', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('77.79.167.196', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"', '"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']
#
#
#  Client ('77.35.53.1', '"Mozilla/5.0 (Windows NT 6.0; rv:34.0) Gecko/20100101 Firefox/34.0"') accessed these pages
#  ['"GET /administrator/ HTTP/1.1"', '"POST /administrator/index.php HTTP/1.1"']

# %% [markdown]
# ### Least 10 frequent sequential patterns

# %%
from google.colab import files
src = list(files.upload().values())[0]
# Out:
#      <input type="file" id="files-5ac54ea2-acd8-4762-ab51-cc5aaa86f17e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ac54ea2-acd8-4762-ab51-cc5aaa86f17e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving GSP.py to GSP.py

# %%
open('GSP.py','wb').write(src)
# Out:
# 4619

# %%
import argparse
import logging
import random
from GSP import GSP
logging.basicConfig(level=logging.DEBUG)
transactions=all_pages

# %%
result = GSP(transactions).search(0.2)
# Out:
# DEBUG:root:
#         Run 1
#         There are 89 candidates.
#         The candidates have been filtered down to 2.
#
# DEBUG:root:
#         Run 2
#         There are 4 candidates.
#         The candidates have been filtered down to 2.
#
# DEBUG:root:
#         Run 3
#         There are 8 candidates.
#         The candidates have been filtered down to 2.
#
# DEBUG:root:
#         Run 4
#         There are 16 candidates.
#         The candidates have been filtered down to 2.
#
# DEBUG:root:
#         Run 5
#         There are 32 candidates.
#         The candidates have been filtered down to 2.
#
# DEBUG:root:
#         Run 6
#         There are 64 candidates.
#         The candidates have been filtered down to 2.
#
# DEBUG:root:
#         Run 7
#         There are 128 candidates.
#         The candidates have been filtered down to 2.
#
# DEBUG:root:
#         Run 8
#         There are 256 candidates.
#         The candidates have been filtered down to 2.
#
# DEBUG:root:
#         Run 9
#         There are 512 candidates.
#         The candidates have been filtered down to 2.
#
# DEBUG:root:
#         Run 10
#         There are 1024 candidates.
#         The candidates have been filtered down to 1.
#
# DEBUG:root:
#         Run 11
#         There are 2048 candidates.
#         The candidates have been filtered down to 0.

# %%
result
# Out:
# [{('"GET /administrator/ HTTP/1.1"',): 401,
#   ('"POST /administrator/index.php HTTP/1.1"',): 400},
#  {('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"'): 399,
#   ('"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"'): 229},
#  {('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"'): 229,
#   ('"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"'): 229},
#  {('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"'): 229,
#   ('"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"'): 155},
#  {('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"'): 155,
#   ('"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"'): 154},
#  {('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"'): 154,
#   ('"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"'): 118},
#  {('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"'): 118,
#   ('"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"'): 118},
#  {('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"'): 118,
#   ('"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"'): 100},
#  {('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"'): 100,
#   ('"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"'): 100},
#  {('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"'): 100}]

# %%
navigation=[]
for i in result:
  navigation.append(list(i.keys()))
navigation
# Out:
# [[('"GET /administrator/ HTTP/1.1"',),
#   ('"POST /administrator/index.php HTTP/1.1"',)],
#  [('"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"'),
#   ('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"')],
#  [('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"'),
#   ('"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"')],
#  [('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"'),
#   ('"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"')],
#  [('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"'),
#   ('"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"')],
#  [('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"'),
#   ('"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"')],
#  [('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"'),
#   ('"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"')],
#  [('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"'),
#   ('"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"')],
#  [('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"'),
#   ('"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"')],
#  [('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"')]]

# %%
l=list(navigation)
l.sort(reverse=True) #sort in reverse order
l
# Out:
# [[('"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"'),
#   ('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"')],
#  [('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"')],
#  [('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"'),
#   ('"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"')],
#  [('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"'),
#   ('"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"')],
#  [('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"'),
#   ('"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"')],
#  [('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"'),
#   ('"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"')],
#  [('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"'),
#   ('"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"')],
#  [('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"'),
#   ('"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"')],
#  [('"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"'),
#   ('"POST /administrator/index.php HTTP/1.1"',
#    '"GET /administrator/ HTTP/1.1"',
#    '"POST /administrator/index.php HTTP/1.1"')],
#  [('"GET /administrator/ HTTP/1.1"',),
#   ('"POST /administrator/index.php HTTP/1.1"',)]]

# %% [markdown]
# ### A graph that shows clusters of users with similar  navigational patterns
